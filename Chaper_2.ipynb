# %% [markdown]
# <a href="https://colab.research.google.com/github/thinnarat007/bsc_dpdm24/blob/main/Chaper_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import data from different formats

# %%
# prompt: mount g deive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Distance

# %% [markdown]
# ##CSV
# extected problem: Encoding Error
#
# solotion: choose the right encoding in the read_csv()

# %%
import pandas as pd
import pandas as pd

file_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/tis_name_02122567.csv'

df = pd.read_csv(file_path, encoding='cp874')
df.head()
# Out:
#    ลำดับ    เลขที่ มอก.                                  ชื่อ มอก. ภาษาไทย  \
# 0      1         2-2525              ขวดแก้วสำหรับเครื่องดื่มประเภทอัดก๊าซ
# 1      2         3-2562                                             น้ำปลา
# 2      3  4 เล่ม 1-2558  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# 3      4  4 เล่ม 2-2552  วิธีมาตรฐานในการวัดอุณหภูมิที่เพิ่มขึ้นของขั้ว...
# 4      5  4 เล่ม 3-2563  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
#
#                                 ชื่อ มอก. ภาษาอังกฤษ ประเภทมาตรฐาน  \
# 0                        Aerated water glass bottles        ทั่วไป
# 1                                         Fish sauce        ทั่วไป
# 2  Tungsten filament lamps for domestics and simi...        บังคับ
# 3  Standard method of measurement of lamp cap tem...        ทั่วไป
# 4  Tungsten filament lamps for domestics and simi...        ทั่วไป
#
#    กลุ่มผลิตภัณฑ์ ชนิดมาตรฐาน BCG Economy ประกาศกระทรวงฯ วันที่  \
# ...

# %% [markdown]
# ##Excel
# extxcted problem:multiple sheets

# %%
# prompt: open excel file for the sheet name X

from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

xfile_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/export62_64.xlsx' # Replace with your actual file path
sheet_name = 'X' # Replace 'X' with the actual sheet name

try:
  df_X= pd.read_excel(xfile_path, sheet_name='Export 63')
  df_X.head()
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except ValueError as e:
  if "No sheet named" in str(e):
    print(f"Error: Sheet '{sheet_name}' not found in the Excel file.")
  else:
    print(f"Error: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_X.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2563            1              1022100          1               C62
# 1      2563            1              1022919          0               C62
# 2      2563            1              1022990          0               C62
# 3      2563            1              1023100          0               C62
# 4      2563            1              1023900          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0        โคตัวผู้                 Bullocks                   14736
# 1          อื่น ๆ                       Other                16995
# 2          อื่น ๆ                       Other                  261
# 3  สำหรับทำพันธุ์  Pure-bred breeding animals                 3460
# 4          อื่น ๆ                       Other                 1349
#
#    มูลค่าส่งออกเงินบาท
# 0            265002594
# 1            326112000
# 2              3444000
# ...

# %% [markdown]
# EXtected problem: table locotion

# %%
xfile_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/export62_64.xlsx' # Replace with your actual file path
sheet_name = 'X' # Replace 'X' with the actual sheet name

df_X= pd.read_excel(xfile_path, sheet_name='Export 64')
df_X.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN  Export 64          NaN                  NaN        NaN
# 1         NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2         NaN       2564            1             01012100        000
# 3         NaN       2564            1             01012900        000
# 4         NaN       2564            1             01022100        001
#
#           Unnamed: 5      Unnamed: 6                  Unnamed: 7  \
# 0                NaN             NaN                         NaN
# 1  หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย
# 2                C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 3                C62          อื่น ๆ                       Other
# 4                C62        โคตัวผู้                 Bullocks
#
#             Unnamed: 8           Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  NaN                  NaN          NaN          NaN
# ...

# %%
# prompt: open sheet number 3 of excel the excel file AND SELECT ONLY TABLE PART

import pandas as pd

xfile_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/export62_64.xlsx'
sheet_name = 'Export 64 '  # Replace with the actual sheet name or sheet index (0-based)

try:
  # Attempt to read the sheet by name first.
  df_sheet3 = pd.read_excel(xfile_path, sheet_name=sheet_name, header=0) # Assuming the first row is the header
except ValueError:
  try:
      #If sheet name doesn't work try sheet number
      df_sheet3 = pd.read_excel(xfile_path, sheet_name=2, header=0) # sheet index 2 corresponds to the third sheet
  except Exception as e:
      print(f"Error: {e}")
      df_sheet3 = pd.DataFrame()  # Create an empty DataFrame if sheet loading fails

df_sheet3.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN  Export 64          NaN                  NaN        NaN
# 1         NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2         NaN       2564            1             01012100        000
# 3         NaN       2564            1             01012900        000
# 4         NaN       2564            1             01022100        001
#
#           Unnamed: 5      Unnamed: 6                  Unnamed: 7  \
# 0                NaN             NaN                         NaN
# 1  หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย
# 2                C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 3                C62          อื่น ๆ                       Other
# 4                C62        โคตัวผู้                 Bullocks
#
#             Unnamed: 8           Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  NaN                  NaN          NaN          NaN
# ...

# %%
xfile_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/export62_64.xlsx'

df_sheet3 = pd.read_excel(xfile_path, sheet_name='Export 64',skiprows=2,usecols=[1,2,3,4]) # sheet index 2 corresponds to the third sheet
df_sheet3.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 0      2564            1              1012100          0
# 1      2564            1              1012900          0
# 2      2564            1              1022100          1
# 3      2564            1              1022919          0
# 4      2564            1              1023100          0

# %%
xfile_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/export62_64.xlsx'

df_sheet3 = pd.read_excel(xfile_path, sheet_name='Export 64',skiprows=2,usecols=range(1,10)) # sheet index 2 corresponds to the third sheet
df_sheet3.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2564            1              1012100          0               C62
# 1      2564            1              1012900          0               C62
# 2      2564            1              1022100          1               C62
# 3      2564            1              1022919          0               C62
# 4      2564            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0  สำหรับทำพันธุ์  Pure-bred breeding animals                   44
# 1          อื่น ๆ                       Other                   35
# 2        โคตัวผู้                 Bullocks                    9674
# 3          อื่น ๆ                       Other                10976
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 3169
#
#    มูลค่าส่งออกเงินบาท
# 0               196720
# 1               182000
# 2            145263681
# ...

# %%
df_sheet3.tail()
# Out:
#       ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 1373      2564            1             25309090          5               KGM
# 1374      2564            1             25309090         90               KGM
# 1375      2564            1             26011110          0               KGM
# 1376      2564            1             26011190          0               KGM
# 1377      2564            1             26011290          0               KGM
#
#                คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 1373        แร่ไพโรฟิลไรท์                 Pyrophylite               272000
# 1374                อื่น ๆ                       Other              2109246
# 1375  แร่เฮมาไทต์และหัวแร่  Haematite and concentrates             42930945
# 1376                อื่น ๆ                       Other                    5
# 1377                อื่น ๆ                       Other                   70
#
#       มูลค่าส่งออกเงินบาท
# ...

# %% [markdown]
# ##GGSheet

# %%
# prompt: open google sheets

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# Open the Google Sheet by its URL
spreadsheet_key = '1PM6pqwO4viKGPmQIs7EyspVov8Jh4oC6PTleeLoxV6E' # Replace with your Google Sheet URL
sh = gc.open_by_key(spreadsheet_key)

# Select a worksheet (by name or index)
worksheet_name = 'Export 62' # Replace with your sheet name
worksheet = sh.worksheet(worksheet_name)

# Get all values from the worksheet
data = worksheet.get_all_values()

# Convert to a Pandas DataFrame
import pandas as pd
df_gsheets = pd.DataFrame(data[1:], columns=data[0])  # Assuming the first row is the header

# Display the first few rows
print(df_gsheets.head())
# Out:
#   ปีแม่แบบ เดือนแม่แบบ พิกัดศุลกากร 8 หลัก รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0     2562           1            01012900       000               C62
# 1     2562           1            01022100       001               C62
# 2     2562           1            01022100       002               C62
# 3     2562           1            01022919       000               C62
# 4     2562           1            01023100       000               C62
#
#       คำอธิบายไทย                    คำอธิบาย น้ำหนัก/ปริมาณสถิติ  \
# 0          อื่น ๆ                       Other                   7
# 1        โคตัวผู้                 Bullocks                   6663
# 2       โคตัวเมีย                        Cows                  36
# 3          อื่น ๆ                       Other               16983
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 746
#
#   มูลค่าส่งออกเงินบาท
# 0              105000
# 1           119934000
# 2             2223000
# 3           362443500
# 4            13055000

# %% [markdown]
# ##JSON

# %%
# prompt: load JSON file name data_station from the drive

import json
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/bsc_dpdm24_data_thin/memo_2298.json'  # Update with the correct path

try:
    with open(file_path, 'r') as f:
        data = json.load(f)
    df_json = pd.DataFrame(data)  # Convert JSON data to DataFrame
    print(df_json.head())
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except json.JSONDecodeError:
    print(f"Error: Invalid JSON format in file {file_path}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    MemoId       DocumentNo  TemplateId            TemplateName  \
# 0    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
# 1    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
#
#                        ToPerson                   CcPerson  CreatorId  \
# 0  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
# 1  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
#
#                        CNameTh                     CNameEn  CPositionId  ...  \
# 0  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
# 1  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
#
#   Amount               RequestDate              ModifiedDate PersonWaitingId  \
# 0    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z            None
# ...

# %%
import json
f=open('/content/drive/MyDrive/bsc_dpdm24_data_thin/memo_2298.json')
json_2298 = json.load(f)
json_2298
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %% [markdown]
# ###Quiz3
# print 'ActorName และ ActionProcess' ของ action history แรก

# %%
import json
fx=open('/content/drive/MyDrive/bsc_dpdm24_data_thin/memo_2298.json')
json_2298 = json.load(fx)
json_2298
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %%
print(json_2298['ActionHistory'][0]['ActorName'], json_2298['ActionHistory'][0]['ActionProcess'])
# Out:
# นางสาวเพิ่มสิน คุณวิสิฏสิริ submit
